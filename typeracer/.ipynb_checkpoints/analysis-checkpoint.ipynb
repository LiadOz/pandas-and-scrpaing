# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
plt.rcParams['figure.figsize'] = (20, 10) # set default size of plots
plt.rcParams.update({'font.size': 20})

# %%
df = pd.read_csv('first221.csv', index_col=0).append(pd.read_csv('220-1729.csv', index_col=0))
df = df.append(pd.read_csv('till5293.csv', index_col=0))
df = df.rename(columns={'Race Number': 'race_number'})
df = df.rename(columns={col:col.lower() for col in df.columns})
df = df.reset_index().drop('index', axis=1)
df.speed = df.speed.apply(lambda x: int(x.split(' ')[0]))
df['timestamp'] = df.date.apply(pd.Timestamp)
df['accuracy'] = df.accuracy.apply(lambda x: float(x[:-1]))
df
# Out:
# C:\Users\Liad\Anaconda3\envs\openbus\lib\site-packages\pandas\core\frame.py:7123: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   sort=sort,
#       accuracy                                             author  \
# 0         93.8                                      Garret Keizer
# 1         93.5                               Wendelin Van Draanen
# 2         93.6                                        James Joyce
# 3         93.5  John F. Hughes, Andries van Dam, James D. Fole...
# 4         93.7                                         Dan Harris
# ...        ...                                                ...
# 5291      94.9                       John Cleese and Connie Booth
# 5292      95.8                                 Douglas Hofstadter
# 5293      95.4                                           Toby Fox
# 5294      94.9                                        John Landis
# 5295      92.7                                       Paulo Coelho
#
#                                  date  \
# 0     Sat, 22 Dec 2018 18:19:52 +0000
# 1     Sat, 22 Dec 2018 18:21:21 +0000
# 2     Sat, 22 Dec 2018 18:22:31 +0000
# 3     Sat, 22 Dec 2018 18:24:32 +0000
# 4     Sat, 22 Dec 2018 18:26:15 +0000
# ...                               ...
# 5291   Sun, 6 Oct 2019 12:09:29 +0000
# 5292   Sun, 6 Oct 2019 12:16:35 +0000
# 5293   Sun, 6 Oct 2019 12:19:27 +0000
# 5294   Sun, 6 Oct 2019 12:23:15 +0000
# 5295   Sun, 6 Oct 2019 12:39:26 +0000
#
#                                               full_text  genre  \
# 0     It is always important, I think, to be clear a...   book
# 1     A million dollars sounds like a lot, I know. E...   book
# 2     Yes, it was her he was looking at, and there w...   book
# 3     The process of determining what pixels should ...   book
# 4     Look at the stars. Same stars as last week, la...  movie
# ...                                                 ...    ...
# 5291  O'Reilly, I have seen more intelligent creatur...  other
# 5292  The paraphrase of Goedel's Theorem says that f...   book
# 5293  When the light is running low, and the shadows...   game
# 5294  Well, you told me I have a plethora. And I jus...  movie
# 5295  In the beginning there was only a small amount...   book
#
#                                           opponents  participants  \
# 0                                               NaN             5
# 1                               dakid02 (3rd place)             5
# 2                  howtokillamokingbird (2nd place)             5
# 3                                               NaN             4
# 4                                               NaN             5
# ...                                             ...           ...
# 5291                            shadyan (2nd place)             5
# 5292                            conargh (1st place)             5
# 5293                      thecomedyne04 (1st place)             5
# 5294  aaronsfury (2nd place) paybtawsan (3rd place)             5
# 5295                                            NaN             5
#
#       race_number            racer  rank  speed  \
# 0               1  Liad (ozonzono)     4     30
# 1               2  Liad (ozonzono)     4     28
# 2               3  Liad (ozonzono)     3     34
# 3               4  Liad (ozonzono)     3     31
# 4               5  Liad (ozonzono)     4     33
# ...           ...              ...   ...    ...
# 5291         5289  Liad (ozonzono)     5     64
# 5292         5290  Liad (ozonzono)     2     59
# 5293         5291  Liad (ozonzono)     3     72
# 5294         5292  Liad (ozonzono)     5     65
# 5295         5293  Liad (ozonzono)     3     60
#
#                                              title  \
# 0                            World Enough and Time
# 1                Sammy Keyes and the Dead Giveaway
# 2                                          Ulysses
# 3       Computer Graphics: Principles and Practice
# 4                                 Imaginary Heroes
# ...                                            ...
# 5291                                 Fawlty Towers
# 5292  Gödel, Escher, Bach: An Eternal Golden Braid
# 5293                                     Deltarune
# 5294                                ¡Three Amigos!
# 5295                       The Devil and Miss Prym
#
#                                                  errors  \
# 0     [('think,', ' instead of ,'), ('clear', 'k ins...
# 1     [('million', 'o instead of i'), ('know.', 'i i...
# 2     [('Yes,', '. instead of ,'), ('was', 'a instea...
# 3     [('process', 's instead of c'), ('determining'...
# 4     [('Same', 's instead of S'), ('as', ' instead ...
# ...                                                 ...
# 5291  [('lying', 't instead of i'), ('on', ' instead...
# 5292  [('that', 'a instead of h'), ('record', 'e ins...
# 5293  [('When', ' instead of n'), ('shadows', 'n ins...
# 5294  [('I', 'i instead of I'), ('just', 's instead ...
# 5295  [('beginning', 'g instead of i'), ('a', 's ins...
#
#                      timestamp
# 0    2018-12-22 18:19:52+00:00
# 1    2018-12-22 18:21:21+00:00
# 2    2018-12-22 18:22:31+00:00
# 3    2018-12-22 18:24:32+00:00
# 4    2018-12-22 18:26:15+00:00
# ...                        ...
# 5291 2019-10-06 12:09:29+00:00
# 5292 2019-10-06 12:16:35+00:00
# 5293 2019-10-06 12:19:27+00:00
# 5294 2019-10-06 12:23:15+00:00
# 5295 2019-10-06 12:39:26+00:00
#
# [5296 rows x 14 columns]

# %% [markdown]
# # WPM And Accuracy Across Time

# %%
N = 20
mean_df = df.groupby(df.race_number // N)['speed'].mean().reset_index()
mean_df['sample_number'] = mean_df.race_number * N

plt.plot(df.race_number, df.speed, label='Original')
plt.plot(mean_df.sample_number, mean_df.speed, color='r', linewidth=4, label='Mean')
plt.title('Races Across Time')
plt.xlabel('Race Number')
plt.ylabel('Speed (WPM)')
plt.legend()
plt.grid(True)
plt.show()

# %%
N = 20
mean_df = df.groupby(df.race_number // N).accuracy.mean().reset_index()
mean_df['sample_number'] = mean_df.race_number * N

plt.plot(df.race_number, df.accuracy, label='Original')
plt.plot(mean_df.sample_number, mean_df.accuracy, color='r', linewidth=4, label='Mean')
plt.title('Accuracy Across Time')
plt.xlabel('Race Number')
plt.ylabel('Accuracy (Percent)')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# # Texts Breakdown

# %%
genre_s = df.genre.value_counts().sort_values()
genre_s = genre_s[genre_s > 5].reset_index()
genre_s['genre_name'] = genre_s['index'].apply(lambda x: x.capitalize())
plt.barh(genre_s.genre_name, genre_s.genre)
plt.title('Genres Count')
plt.xlabel('Appearences')
plt.show()

# %%
plt.pie(genre_s.genre, labels=genre_s.genre_name, autopct='%1.1f%%', wedgeprops={'edgecolor': 'black'})
plt.title('Genres Pie Chart')
plt.show()

# %%
def append_title_count(original_df, titles, last_race):
    # Finding the top values in the first number of races
    filtered = df[(df.title.isin(titles.columns)) & (df.race_number < last_race)].title.value_counts()
    # Creating a dataframe which would be appended taking the values from the filtered dataframe
    app = titles.copy().iloc[0]
    for col in app.index:
        try:
            app[col] = filtered[col]
        except:
            app[col] = 0
    return titles.append(app)
    
# The dataframe with the titles that appear the most
titles = df.title.value_counts().head(5).to_frame().transpose().reset_index().drop('index', axis=1)
for x in range(df.shape[0] // 100):
    titles = append_title_count(df, titles, x * 100)

# Moving the first entry to last
titles = titles.apply(np.roll, shift=-1).reset_index().drop('index', axis=1)

# %%
plt.stackplot([x * 100 for x in titles.index], [titles[x] for x in titles.columns], labels=[x for x in titles.columns])
plt.legend(loc='upper left')
plt.show()

# %%
df['hour'] = df.timestamp.dt.hour
df.groupby('hour')['speed'].mean().plot(title='Speed Per Hour')

# %% [markdown]
# # Fingers Typing Distance

# %%
DISTANCE_KEYS = [None] * 5
DISTANCE_KEYS[0] = {'a', 's', 'e', 'f', 'j', 'i', 'l', ';', ' '}
DISTANCE_KEYS[1] = {'q', 'w', 'd', 'r', 't', 'y', 'u', 'o', 'p', '[',
                     'g', 'h', 'k', "'", 'z', 'x', 'v', 'b', 'n', 'm', ',', '.', '/', '8', '3'}
DISTANCE_KEYS[2] = {']', '\\', ',', 'c', '`', '1', '2', '4', '5', '6', '7', '9', '0', '-', '=',
                    'A', 'S', 'E', 'F', 'J', 'I', 'L', ':'}
DISTANCE_KEYS[3] = {'Q', 'W', 'D', 'R', 'T', 'Y', 'U', 'O', 'P', '{',
                     'G', 'H', 'K', '"', 'Z', 'X', 'V', 'B', 'N', 'M', '<', '>', '?', '*', '#'}
DISTANCE_KEYS[4] = {'}', '|', '<', 'C', '~', '!', '@', '$', '%', '^', '&', '(', ')', '_', '+'}
# Distance in m
KEYS_DISTANCE = 0.016

# %%
def key_distance(char):
    for i, option in enumerate(DISTANCE_KEYS):
        if char in option:
            return i

def distance_traveled(text):
    distance = 0
    for char in text:
        distance += key_distance(char) * KEYS_DISTANCE
    return distance

df['distance'] = df.full_text.apply(distance_traveled)
print(df.distance.sum() / 1000, 'km')
# Out:
# 11.982336000000009 km

# %% [markdown]
# # Typos Breakdown

# %%
import ast
err = df[['race_number', 'errors']].copy()
err.errors = err.errors.apply(ast.literal_eval)
err = err.set_index('race_number').errors.apply(pd.Series).stack().reset_index() \
        .drop('level_1', axis=1).rename(columns={0: 'mistake'})
err['word'] = err.mistake.apply(lambda x: x[0])
err['detail'] = err.mistake.apply(lambda x: x[1])
err['expected'] = err.detail.apply(lambda x: x[-1])
err['typed'] = err.detail.apply(lambda x: x[0])
err
# Out:
#        race_number                         mistake          word  \
# 0                1         (think,,  instead of ,)        think,
# 1                1         (clear, k instead of l)         clear
# 2                1          (you:, t instead of y)          you:
# 3                1     (important,,  instead of ,)    important,
# 4                1          (than, e instead of a)          than
# ...            ...                             ...           ...
# 47419         5293           (and, i instead of a)           and
# 47420         5293  (unimportant,, i instead of u)  unimportant,
# 47421         5293            (and,  instead of d)           and
# 47422         5293         (where, e instead of h)         where
# 47423         5293          (ended,  instead of d)         ended
#
#                detail expected typed
# 0        instead of ,        ,
# 1      k instead of l        l     k
# 2      t instead of y        y     t
# 3        instead of ,        ,
# 4      e instead of a        a     e
# ...               ...      ...   ...
# 47419  i instead of a        a     i
# 47420  i instead of u        u     i
# 47421    instead of d        d
# 47422  e instead of h        h     e
# 47423    instead of d        d
#
# [47424 rows x 6 columns]

# %%
from key_distance import find_distance
err['distance'] = err.apply(lambda x: find_distance(x['expected'], x['typed']), axis=1)
err
# Out:
#        race_number                         mistake          word  \
# 0                1         (think,,  instead of ,)        think,
# 1                1         (clear, k instead of l)         clear
# 2                1          (you:, t instead of y)          you:
# 3                1     (important,,  instead of ,)    important,
# 4                1          (than, e instead of a)          than
# ...            ...                             ...           ...
# 47419         5293           (and, i instead of a)           and
# 47420         5293  (unimportant,, i instead of u)  unimportant,
# 47421         5293            (and,  instead of d)           and
# 47422         5293         (where, e instead of h)         where
# 47423         5293          (ended,  instead of d)         ended
#
#                detail expected typed     distance
# 0        instead of ,        ,        Space Error
# 1      k instead of l        l     k            1
# 2      t instead of y        y     t            1
# 3        instead of ,        ,        Space Error
# 4      e instead of a        a     e            3
# ...               ...      ...   ...          ...
# 47419  i instead of a        a     i            8
# 47420  i instead of u        u     i            1
# 47421    instead of d        d        Space Error
# 47422  e instead of h        h     e            4
# 47423    instead of d        d        Space Error
#
# [47424 rows x 7 columns]

# %%
err.distance.value_counts()
# Out:
# 1              12992
# 3               6351
# 2               6071
# 5               4774
# 4               4692
# Space Error     4105
# 6               2709
# 0               2028
# 7               1898
# 8               1126
# 9                486
# 10               154
# 12                16
# 11                15
# 13                 3
# 1988               2
# 1992               1
# 1990               1
# Name: distance, dtype: int64

# %%
err.detail.value_counts().head(20)
# Out:
#  instead of ,     709
# a instead of e    707
# e instead of i    612
# i instead of o    593
# e instead of r    577
# o instead of i    547
# s instead of d    536
# d instead of s    532
# e instead of a    495
# t instead of n    477
# h instead of t    476
#  instead of e     472
# e instead of w    459
# a instead of h    445
# e instead of h    440
#  instead of .     420
# r instead of e    420
# a instead of w    415
# a instead of s    409
# t instead of i    402
# Name: detail, dtype: int64
